# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('Supply Chain & Sales Datasets.xlsx - Retail Order.csv')

# %%
df.head()
# Out:
#    Retail Order ID        Order ID     Order Date      Ship Date  \
# 0                1  CA-2016-152156   8/11/16 0:00  11/11/16 0:00
# 1                2  CA-2016-152156   8/11/16 0:00  11/11/16 0:00
# 2                3  CA-2016-138688   12/6/16 0:00   12/6/16 0:00
# 3                4  US-2015-108966  11/10/15 0:00  11/10/15 0:00
# 4                5  US-2015-108966  11/10/15 0:00  11/10/15 0:00
#
#         Ship Mode Customer ID    Customer Name    Segment  Postal Code  \
# 0    Second Class    CG-12520      Claire Gute   Consumer        42420
# 1    Second Class    CG-12520      Claire Gute   Consumer        42420
# 2    Second Class    DV-13045  Darrin Van Huff  Corporate        90036
# 3  Standard Class    SO-20335   Sean O'Donnell   Consumer        33311
# 4  Standard Class    SO-20335   Sean O'Donnell   Consumer        33311
#
#          Country  ...         Category Returned     Sales Quantity Discount  \
# ...

# %%
# Check data information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Retail Order ID      9994 non-null   int64
#  1   Order ID             9994 non-null   object
#  2   Order Date           9994 non-null   object
#  3   Ship Date            9994 non-null   object
#  4   Ship Mode            9994 non-null   object
#  5   Customer ID          9994 non-null   object
#  6   Customer Name        9994 non-null   object
#  7   Segment              9994 non-null   object
#  8   Postal Code          9994 non-null   int64
#  9   Country              9994 non-null   object
#  10  City                 9994 non-null   object
#  11  State                9994 non-null   object
#  12  Region               9994 non-null   object
#  13  latitude             9994 non-null   object
#  14  longitude            9994 non-null   object
# ...

# %%
for col in df.select_dtypes(include='object').columns:
  df[col] = df[col].str.replace(",", ".", regex=True)

# %%
df.head()
# Out:
#    Retail Order ID        Order ID     Order Date      Ship Date  \
# 0                1  CA-2016-152156   8/11/16 0:00  11/11/16 0:00
# 1                2  CA-2016-152156   8/11/16 0:00  11/11/16 0:00
# 2                3  CA-2016-138688   12/6/16 0:00   12/6/16 0:00
# 3                4  US-2015-108966  11/10/15 0:00  11/10/15 0:00
# 4                5  US-2015-108966  11/10/15 0:00  11/10/15 0:00
#
#         Ship Mode Customer ID    Customer Name    Segment  Postal Code  \
# 0    Second Class    CG-12520      Claire Gute   Consumer        42420
# 1    Second Class    CG-12520      Claire Gute   Consumer        42420
# 2    Second Class    DV-13045  Darrin Van Huff  Corporate        90036
# 3  Standard Class    SO-20335   Sean O'Donnell   Consumer        33311
# 4  Standard Class    SO-20335   Sean O'Donnell   Consumer        33311
#
#          Country  ...         Category Returned     Sales Quantity Discount  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Retail Order ID      9994 non-null   int64
#  1   Order ID             9994 non-null   object
#  2   Order Date           9994 non-null   object
#  3   Ship Date            9994 non-null   object
#  4   Ship Mode            9994 non-null   object
#  5   Customer ID          9994 non-null   object
#  6   Customer Name        9994 non-null   object
#  7   Segment              9994 non-null   object
#  8   Postal Code          9994 non-null   int64
#  9   Country              9994 non-null   object
#  10  City                 9994 non-null   object
#  11  State                9994 non-null   object
#  12  Region               9994 non-null   object
#  13  latitude             9994 non-null   object
#  14  longitude            9994 non-null   object
# ...

# %%
df = df.apply(pd.to_numeric, errors="ignore")
# Out:
# <ipython-input-21-5515412a2a49>:1: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df = df.apply(pd.to_numeric, errors="ignore")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Retail Order ID      9994 non-null   int64
#  1   Order ID             9994 non-null   object
#  2   Order Date           9994 non-null   object
#  3   Ship Date            9994 non-null   object
#  4   Ship Mode            9994 non-null   object
#  5   Customer ID          9994 non-null   object
#  6   Customer Name        9994 non-null   object
#  7   Segment              9994 non-null   object
#  8   Postal Code          9994 non-null   int64
#  9   Country              9994 non-null   object
#  10  City                 9994 non-null   object
#  11  State                9994 non-null   object
#  12  Region               9994 non-null   object
#  13  latitude             9994 non-null   float64
#  14  longitude            9994 non-null   float64
# ...

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], format ="mixed")
df['Ship Date'] = pd.to_datetime(df['Ship Date'], format = "mixed")

# %%
df.loc[df['Customer ID']=='CG-12520']
# Out:
#       Retail Order ID        Order ID Order Date  Ship Date     Ship Mode  \
# 0                   1  CA-2016-152156 2016-08-11 2016-11-11  Second Class
# 1                   2  CA-2016-152156 2016-08-11 2016-11-11  Second Class
# 5491             5492  CA-2017-164098 2017-01-26 2017-01-27   First Class
# 6877             6878  US-2015-123918 2015-10-15 2015-10-15      Same Day
# 6878             6879  US-2015-123918 2015-10-15 2015-10-15      Same Day
#
#      Customer ID Customer Name   Segment  Postal Code        Country  \
# 0       CG-12520   Claire Gute  Consumer        42420  United States
# 1       CG-12520   Claire Gute  Consumer        42420  United States
# 5491    CG-12520   Claire Gute  Consumer        77070  United States
# 6877    CG-12520   Claire Gute  Consumer        75217  United States
# 6878    CG-12520   Claire Gute  Consumer        75217  United States
#
#            City     State   Region   latitude  longitude Retail Sales People  \
# ...

# %%
# Check duplicated
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# There is no duplicated records either

# %%
df.describe()
# Out:
#        Retail Order ID                     Order Date  \
# count      9994.000000                           9994
# mean       4997.500000  2016-04-11 07:17:44.078447104
# min           1.000000            2014-01-02 00:00:00
# 25%        2499.250000            2015-05-01 00:00:00
# 50%        4997.500000            2016-05-30 00:00:00
# 75%        7495.750000            2017-04-09 00:00:00
# max        9994.000000            2017-12-30 00:00:00
# std        2885.163629                            NaN
#
#                            Ship Date   Postal Code     latitude    longitude  \
# count                           9994   9994.000000  9994.000000  9994.000000
# mean   2016-05-15 21:54:47.332399360  55190.379428    38.519631   -94.773589
# min              2014-01-15 00:00:00   1040.000000    27.664827  -120.740139
# 25%              2015-06-20 00:00:00  23223.000000    35.759573  -119.417932
# 50%              2016-07-21 00:00:00  56430.500000    37.964253   -89.398528
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Retail Order ID      9994 non-null   int64
#  1   Order ID             9994 non-null   object
#  2   Order Date           9994 non-null   datetime64[ns]
#  3   Ship Date            9994 non-null   datetime64[ns]
#  4   Ship Mode            9994 non-null   object
#  5   Customer ID          9994 non-null   object
#  6   Customer Name        9994 non-null   object
#  7   Segment              9994 non-null   object
#  8   Postal Code          9994 non-null   int64
#  9   Country              9994 non-null   object
#  10  City                 9994 non-null   object
#  11  State                9994 non-null   object
#  12  Region               9994 non-null   object
#  13  latitude             9994 non-null   float64
#  14  longitude            9994 non-null   float64
# ...

# %%
df.to_excel('Supply Chain & Sales.xlsx', index=False)
from google.colab import files
files.download('Supply Chain & Sales.xlsx')
